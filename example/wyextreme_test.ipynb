# %% [markdown]
# # `wyextreme`: A Python Package for GEV or GEV-shift fit
#
# * Wenchang Yang
# * Department of Geosciences, Princeton University

# %%
run -m wyextreme.gev_shift test mu0=25 sigma=2 xi=-0.1 alpha=3
# Out:
# [2021-07-11_23:53:49]: start /tigress/wenchang/analysis/heatwave2021/test/example/wyextreme/gev_shift.py
#
# [2021-07-11_23:53:49]: end import; **0** seconds from "start /tigress/wenchang/analysis/heatwave2021/test/example/wyextreme/gev_shift.py"
# true params:     mu0=25; sigma=2; xi=-0.1; alpha=3
# wy fit params:   mu0=25.35; sigma=1.845; xi=-0.3134; alpha=2.848
# wy fit params:   mu0=25.35; sigma=1.845; xi=-0.3134; alpha=2.848
# 100%|██████████| 100/100 [00:02<00:00, 48.40it/s]
#      mu0 and 95% CI: 25.35(24.49, 26.15)
#    sigma and 95% CI: 1.845(1.603, 2.045)
#       xi and 95% CI: -0.3134(-0.429, -0.2058)
#    alpha and 95% CI: 2.848(2.169, 3.596)
#
# wy fit params:   mu0=25.35; sigma=1.845; xi=-0.3134; alpha=2.848
#
#      mu0 and 95% CI: 25.35(24.49, 26.15)
#    sigma and 95% CI: 1.845(1.603, 2.045)
#       xi and 95% CI: -0.3134(-0.429, -0.2058)
#    alpha and 95% CI: 2.848(2.169, 3.596)
#
# $\mu_0$: 25.35(true:25); 95% CI: (24.49, 26.15)
# $\sigma$: 1.845(true:2); 95% CI: (1.603, 2.045)
# $\xi$: -0.3134(true:-0.1); 95% CI: (-0.429, -0.2058)
# $\alpha$: 2.848(true:3); 95% CI: (2.169, 3.596)
#
#
# [2021-07-11_23:53:52]: **Done**; **2** seconds from "start /tigress/wenchang/analysis/heatwave2021/test/example/wyextreme/gev_shift.py"
